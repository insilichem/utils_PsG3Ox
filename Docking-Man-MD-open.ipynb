# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from astropy.visualization import hist

# %% [markdown]
# ## Global docking

# %%
info_open = pd.read_csv("./Analysis-score.csv", low_memory=False)
#See best distance solutions
info_open.head(400)
# Out:
#     ObjN Binding_Mode  Dist_Hcat_ligand  Dist_ligand_FAD  Dist55  Dist94  \
# 0      1           C2             2.264            2.999  11.428   2.068
# 1      2           C2             2.057            3.360  10.238   2.089
# 2      3           C2             2.332            3.371  10.108   2.609
# 3      4           C2             3.901            3.864   9.684   2.055
# 4      5           C2             2.610            2.812   9.083   1.969
# 5      6           C2             3.269            2.764   6.936   2.392
# 6      7           C2             3.286            3.540   8.063   2.330
# 7      8           C2             5.761            2.779   6.761   2.026
# 8      9           C3             5.468            2.438   9.055   3.149
# 9     10           C3             4.523            3.736  11.665   2.043
# 10    11           C3             4.043            2.594   3.152   1.983
# 11    12           C3             1.836            3.585   7.757   2.310
# ...

# %%
info_open["Binding_Energy"].mean()
# Out:
# 104.41622222222222

# %%
info_semi_open = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/01-Glucose/from_MDs/semi_open/Analysis-score.csv", low_memory=False)
#See best distance solutions
info_semi_open.head(270)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 info_semi_open = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/01-Glucose/from_MDs/semi_open/Analysis-score.csv", low_memory=False)
#       2 #See best distance solutions
#       3 info_semi_open.head(270)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
info_semi_open["Binding_Energy"].mean()

# %%
#See best energy solutions
infoEwt = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_byE-WT.csv", low_memory=False)
infoEwt.head(20)

# %%
infoE2f4 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_byE-2F4.csv", low_memory=False)
#See best distance solutions
infoE2f4.head(20)
# Out:
#      STRUCTURE  Dist ABTS-T1  Binding energy  Dist ABTS-TNC  Dist Cu-loop  \
# 0   c1-088_001        12.616         -11.083          4.663        14.127
# 1   c1-088_002        12.843         -11.066          4.503        14.127
# 2   c1-231_001        13.148         -10.726          5.191        12.700
# 3   c1-133_001        13.066         -10.664          4.379        13.995
# 4   c1-307_001        12.904         -10.499          4.629        12.552
# 5   c1-133_002        13.163         -10.488          4.591        13.995
# 6   c1-117_001        13.015         -10.390          4.949        14.957
# 7   c1-179_001        12.620         -10.367          4.672        13.168
# 8   c1-307_002        12.578         -10.363          4.391        12.552
# 9   c1-281_001        13.536         -10.346          4.505        12.839
# 10  c1-134_001        13.483         -10.338          4.394        14.155
# 11  c1-291_001        12.700         -10.325          5.008        12.657
# ...

# %%
#Trying to find correlation between closest and better E and closed loop  WT global
sns.jointplot(data=info_open[ (info_open["Binding_Mode"] == 'C3')], x="Dist_ligand_FAD", y="Dist345",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Mode"] == 'C3')], x="Dist_Hcat_ligand", y="Dist345",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Energy"] < 200)], x="Dist55", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Energy"] < 200)], x="Dist94", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Energy"] < 200)], x="Dist129", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Energy"] < 200)], x="Dist297", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Energy"] < 200)], x="Dist340", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (info_open["Binding_Energy"] < 200)], x="Dist345", y="Binding_Energy",color='steelblue', alpha=0.6)

# %%
sns.jointplot(data=info_open[ (info_open["Binding_Mode"] == 'C3')], x="Dist_Hcat_ligand", y="Dist345",color='steelblue', alpha=0.6)
plt.savefig("./H440-D345.png", bbox_inches='tight', dpi=600)

# %%
sns.jointplot(data=info_open[ (info_open["Binding_Mode"] == 'C3')], x="Dist_ligand_FAD", y="Dist345",color='steelblue', alpha=0.6)
plt.savefig("./FAD-D345.png", bbox_inches='tight', dpi=600)

# %%
#Trying to find correlation between closest and better E and closed loop  WT global
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)], x="Dist_ligand_FAD", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)], x="Dist_Hcat_ligand", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)],x="Dist55", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)], x="Dist94", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)],x="Dist129", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)],x="Dist297", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)],x="Dist340", y="Binding_Energy",color='steelblue', alpha=0.6)
sns.jointplot(data=info_semi_open[ (info_semi_open["Binding_Energy"] < 200)],x="Dist345", y="Binding_Energy",color='steelblue', alpha=0.6)

# %%
infoall = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/from_MDs/semi_open/Analysis.csv", low_memory=False)
infoall.tail(40)
#sns.jointplot(data=infoall[ (infoall["Binding energy"] < -5) & (infoall["DOCKING_POSE"] < 4)], x="Dist ABTS-T1", y="Binding energy")
# Out:
#    Conformation  Dist_Hcat_ligand  Dist_ligand_FAD  Dist94_1  Dist94_2  \
# 0            C2             4.279            2.413     3.179     3.461
# 1            C2             4.971            2.764     3.311     3.462
# 2            C2             4.395            2.575     3.187     3.534
# 3            C2             4.117            4.522     5.121     4.485
# 4            C2             4.043            2.300     3.212     3.402
# 5            C2             2.434            3.801     4.820     3.625
# 6            C3             5.905            4.792     5.248     5.248
# 7            C3             4.335            3.429     6.506     6.506
# 8            C3             2.149            2.393     4.170     4.170
# 9            C3             5.111            4.558     5.333     5.333
# 10           C3             2.106            2.312     4.562     4.562
# 11           C3             2.573            2.536     3.646     3.646
# ...

# %%
# Examples on one type of graphs:
ax = sns.scatterplot(x=infoall.Dist_ligand_FAD, y=infoall.Dist_ligand_FAD,
                     hue=infoall.Conformation, style=infoall.Conformation)
ax.set(xlim=(0, 6))
ax.set(ylim=(0,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_73217/4075279453.py in <module>
#       1 # Examples on one type of graphs:
# ----> 2 ax = sns.scatterplot(x=infoall.Dist_ligand_FAD, y=infoall.Dist_ligand_FAD,
#       3                      hue=infoall.Conformation, style=infoall.Conformation)
#       4 ax.set(xlim=(0, 6))
#       5 ax.set(ylim=(0,6))
#
# NameError: name 'infoall' is not defined

# %%
g = sns.pairplot(data=info_open[['Binding_Energy','Dist_Hcat_ligand','Dist_ligand_FAD','Dist55','Dist94','Dist129','Dist297','Dist340','Dist345','Energy_ligand','Score','Binding_Mode']], hue='Binding_Mode')
#g = sns.pairplot(data=info_semi_open[['Binding_Energy','Dist_Hcat_ligand','Dist_ligand_FAD','Dist94','Dist129','Dist297','Dist340','Energy_ligand','Conformation']], hue='Conformation')

# %%
###Seaborn does not alow jointplot with scatter and hist of two data sets. 
##The hist will be only for one of the sets!!!

# %%
#Script tipus Lur
# lists X, Y for series 1
#maxBindE_list_ALLAA = [yourlist]
#totS_list_ALLAA = [yourlist]

# lists X, Y for series 2
#maxBindE_list_PIKAA = [yourlist]
#totS_list_PIKAA = [yourlist]


# determine 1) lenght of your data (N), 2) list on X and 3) list on Y
#Read WT data
dfopen = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/01-Open-loop/Analysis.csv")

#N_A = len(maxBindE_list_ALLAA)
X_open = dfopen["Dist340_1"].values
Y_open = dfopen["Binding_Energy"].values

#Read 2f4 data
dfsemi = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/02-SemiOpen-loop/Analysis.csv")

#N_A = len(maxBindE_list_ALLAA)
X_semi = dfsemi["Dist340_1"].values
Y_semi = dfsemi["Binding_Energy"].values


#N_P = len(maxBindE_list_PIKAA)

# Create data
#N = N_A + N_P # total lenght, do not need to change (specified before)
group1 = (np.array(X_open), np.array(Y_open))
group2 = (np.array(X_semi), np.array(Y_semi))

data = (group1, group2)
colors = ("steelblue", "orange")      # choose colors
groups = ("open", "semi")    # choose legend


# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=(0.6), c=color, edgecolors='none', s=50, label=group)

plt.title('Glucose Docking')
plt.legend(loc=4)
plt.xlabel("Distance 340_1-Glc (A)", fontsize=14)
plt.ylabel("Binding Energy (kcal/mol)", fontsize=14)
plt.ylim(20,100)
plt.xlim(0,10)
plt.savefig("./dock-Glc_blueorange.png", bbox_inches='tight', dpi=600)

# %%
# Binding energy vs Dist ABTS-T1 global
df = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT.csv")
x = dfopen["Dist340_1"].values
y = dfopen["Binding_Energy"].values

distCu = df["Dist Cu-loop"].values

df2 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4.csv")
x2 = df2["Dist ABTS-T1"].values
y2 = df2["Binding energy"].values

#Plot figure
plt.figure(figsize=(8,8))
plt.plot(x, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2, y2, "x", c="orange", markersize=8, alpha=0.8, label='2F4')

plt.xlabel("Distance from T1 Cu (ang)", fontsize=22)
plt.ylabel("Binding energy (kcal/mol)", fontsize=22)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.title ("ABTS global docking", fontsize=14)
plt.ylim(-12,-5)
plt.xlim(0,30)
plt.legend(loc=4, fontsize=20)
plt.savefig("./VINADocking_global-notitle-blueorange.png", bbox_inches='tight', dpi=350)
#plt.clf()

# %% [markdown]
# ## Site B

# %%
# Binding energy vs Dist ABTS-T1 SITEB
dfB = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT-siteB-pose3.csv")
x = dfB["Dist ABTS-T1"].values
xH451 = dfB["Dist ABTS-H451"].values
y = dfB["Binding energy"].values

distCu = dfB["Dist Cu-loop"].values

dfB2 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4-siteB-pose3.csv")
x2 = dfB2["Dist ABTS-T1"].values
x2H451 = dfB2["Dist ABTS-H451"].values
y2 = dfB2["Binding energy"].values

dist2Cu = dfB2["Dist Cu-loop"].values

#Plot figure
plt.figure(figsize=(8,8))
plt.plot(x, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2, y2, "x", c="orange", markersize=5, label='2F4')

plt.xlabel("Distance ABTS to T1 Cu (ang)", fontsize=22)
plt.ylabel("Binding energy (kcal/mol)", fontsize=22)
#plt.title ("ABTS siteB docking", fontsize=14)
plt.ylim(-12,-5)
plt.xlim(0,25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc=4,fontsize=20)
plt.savefig("./WT-2F4-VINADocking_siteB-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot vs H451 distance
plt.figure(figsize=(8,8))
plt.plot(xH451, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2H451, y2, "x", c="orange", markersize=5, label='2F4')

plt.xlabel("Distance ABTS to H451 (ang)", fontsize=22)
plt.ylabel("Binding energy (kcal/mol)", fontsize=22)
#plt.title ("ABTS siteB docking", fontsize=14)
plt.ylim(-12,-5)
plt.xlim(0,25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc=4,fontsize=20)
plt.savefig("./VINADocking_siteB_H451-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot loop vs H451 distance
plt.figure(figsize=(8,8))
plt.plot(xH451, distCu, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2H451, dist2Cu, "x", c="orange", markersize=5, label='2F4', alpha=0.4)

plt.xlabel("Distance ABTS to H451 (ang)", fontsize=22)
plt.ylabel("Distance Cu-loop (ang)", fontsize=22)
#plt.title ("ABTS siteB docking", fontsize=14)
plt.ylim(10,30)
plt.xlim(0,25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc=4,fontsize=20)
plt.savefig("./VINADocking_siteB_H451_distCu-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

# %%
##Histogram of distances SITEB
dfopen = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/02-SemiOpen-loop/Analysis.csv")
dfsemi = pd.read_csv("~/Documents/AsP2Ox/05-newmodel/00-Dockings/13-new-script/01-Open-loop/Analysis.csv")

# %%
#ABTS-T1 distance siteB
plt.figure(figsize=(8,8))
histopen = dfopen["Dist340_1"].hist(bins=40, facecolor='steelblue', label='open', alpha=0.8)
histsemi = dfsemi["Dist340_1"].hist(bins=40, facecolor='orange', label='semi', alpha=0.8)
plt.xlabel("Distance 340_1-Glc", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,6)
plt.grid(axis='x')
plt.xlim(2,6)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(loc='best')
plt.savefig("./Docking-Glc-340-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-T1 distance siteB T1<10ang
plt.figure(figsize=(8,8))
hist2f4 = df2f4B["Dist ABTS-T1"].hist(bins=40, facecolor='orange', label='2f4', alpha=0.8)
histwt = dfwtB["Dist ABTS-T1"].hist(bins=40, facecolor='steelblue', label='wt', alpha=0.9)

plt.xlabel("Distance ABTS to T1 Cu (ang)", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,250)
plt.grid(axis='x')
plt.xlim(0,12.5)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(loc='best')
plt.savefig("./VINADocking_siteB_histo-T1-125ang-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-H514 distance siteB
histwth514 = dfwtB["Dist ABTS-H514"].hist(bins=40, facecolor='steelblue', alpha=0.8)
hist2f4h514 = df2f4B["Dist ABTS-H514"].hist(bins=40, facecolor='orange', alpha=0.8)
plt.xlabel("Distance ABTS to H514 (ang)", fontsize=14)
plt.ylabel("Number of events", fontsize=14)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig("./VINADocking_siteB_histo-H514-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-H451 distance siteB
histwth451 = dfwtB["Dist ABTS-H451"].hist(bins=40, facecolor='steelblue', alpha=0.8)
hist2f4h451 = df2f4B["Dist ABTS-H451"].hist(bins=40, facecolor='orange', alpha=0.8)
plt.xlabel("Distance ABTS to H451 (ang)", fontsize=14)
plt.ylabel("Number of events", fontsize=14)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig("./VINADocking_siteB_histo-H451-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-H451 and H514 distance siteB
plt.figure(figsize=(8,8))
histwth451 = dfwtB["Dist ABTS-H451"].hist(bins=40, facecolor='steelblue', alpha=0.8)
hist2f4h451 = df2f4B["Dist ABTS-H451"].hist(bins=40, facecolor='orange', alpha=0.8)
histwth514 = dfwtB["Dist ABTS-H514"].hist(bins=40, facecolor='lightslategrey', alpha=0.9)
hist2f4h514 = df2f4B["Dist ABTS-H514"].hist(bins=40, facecolor='tan', alpha=0.7)
plt.xlabel("Distance ABTS to His514 and His451 (ang)", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./VINADocking_siteB_histo-H451-H514-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-H451 and H514 distance siteB
plt.figure(figsize=(8,8))
histwth451 = dfwtB["Dist ABTS-H451"].hist(bins=40, facecolor='steelblue', alpha=0.8)
hist2f4h451 = df2f4B["Dist ABTS-H451"].hist(bins=40, facecolor='orange', alpha=0.8)
histwth514 = dfwtB["Dist ABTS-H514"].hist(bins=40, facecolor='lightslategrey', alpha=0.8)
hist2f4h514 = df2f4B["Dist ABTS-H514"].hist(bins=40, facecolor='tan', alpha=0.7)
plt.xlabel("Distance ABTS to His514 and His451 (ang)", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,12)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./VINADocking_siteB_histo-H451-H514-12A-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#Dist ABTS to T1<12 ALL WT siteB
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfwtB[ (dfwtB["Binding energy"] < -6) & (dfwtB["DOCKING_POSE"] < 4) & (dfwtB["Dist ABTS-T1"] <=12)], x="Dist ABTS-T1", y="Binding energy", color='steelblue', alpha=1,xlim=[0,12],ylim=[-10.,-6])
ax.ax_joint.set_xlabel('Distance ABTS to T1 Cu (ang)', size=18)
ax.ax_joint.set_ylabel('Binding energy (kcal/mol)', size=18)
ax.ax_joint.set_xticklabels([0,2,4,6,8,10,12], size = 16)
ax.ax_joint.set_yticklabels([-10.0,-9.5,-9.0,-8.5,-8.0,-7.5,-7.0,-6.5,-6.0], size = 16)
# Out:
# [Text(0,-10,'-10.0'),
#  Text(0,-9.5,'-9.5'),
#  Text(0,-9,'-9.0'),
#  Text(0,-8.5,'-8.5'),
#  Text(0,-8,'-8.0'),
#  Text(0,-7.5,'-7.5'),
#  Text(0,-7,'-7.0'),
#  Text(0,-6.5,'-6.5'),
#  Text(0,-6,'-6.0')]

# %%
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfopen[ (dfopen["Binding_Energy"] < 100)], x="Dist340_2", y="Binding_Energy", color='steelblue', alpha=0.4,xlim=[2,6],ylim=[20,100])
ax.ax_joint.set_xlabel('Distance 340_1-Glc', size=18)
ax.ax_joint.set_ylabel('Binding Energy (kcal/mol)', size=18)


plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfsemi[ (dfsemi["Binding_Energy"] < 100)], x="Dist340_2", y="Binding_Energy", color='steelblue', alpha=0.4,xlim=[2,6],ylim=[20,100])
ax.ax_joint.set_xlabel('Distance 340_1-Glc', size=18)
ax.ax_joint.set_ylabel('Binding Energy (kcal/mol)', size=18)
# Out:
# Text(23.875, 0.5, 'Binding Energy (kcal/mol)')

# %%
#Dist H451<8 ALL WT siteB
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfwtB[ (dfwtB["Binding energy"] < -6) & (dfwtB["DOCKING_POSE"] < 4) & (dfwtB["Dist ABTS-H451"] <=10)], x="Dist ABTS-H451", y="Binding energy", color='steelblue', alpha=0.4,xlim=[0,10],ylim=[-10.,-6])
ax.ax_joint.set_xlabel('Distance ABTS to H451 (ang)', size=18)
ax.ax_joint.set_ylabel('Binding energy (kcal/mol)', size=18)
ax.ax_joint.set_xticklabels([0,2,4,6,8,10], size = 16)
ax.ax_joint.set_yticklabels([-10.0,-9.5,-9.0,-8.5,-8.0,-7.5,-7.0,-6.5,-6.0], size = 16)
plt.savefig("./VINADocking_siteB_histo-H451-10A-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#Dist H451<12 ALL WT siteB
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfwtB[ (dfwtB["Binding energy"] < -6) & (dfwtB["DOCKING_POSE"] < 4) & (dfwtB["Dist ABTS-H451"] <=12)], x="Dist ABTS-H451", y="Binding energy", color='steelblue', alpha=0.6,xlim=[0,12],ylim=[-10.,-6])
ax.ax_joint.set_xlabel('Distance ABTS to H451 (ang)', size=18)
ax.ax_joint.set_ylabel('Binding energy (kcal/mol)', size=18)
ax.ax_joint.set_xticklabels([0,2,4,6,8,10,12], size = 16)
ax.ax_joint.set_yticklabels([-10.0,-9.5,-9.0,-8.5,-8.0,-7.5,-7.0,-6.5,-6.0], size = 16)
plt.savefig("./VINADocking_siteB_histo-H451-12A-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ADist loop-Cu for ALL 2F4 siteB
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=df2f4B[ (df2f4B["Binding energy"] < -4) & (df2f4B["DOCKING_POSE"] < 4) & (df2f4B["Dist ABTS-H451"] <=40)], x="Dist Cu-loop", y="Binding energy", color='orange', alpha=0.4,xlim=[10,30],ylim=[-9.5,-4])
ax.ax_joint.set_xlabel('Distance Met-loop to T1 Cu (ang)', size=18)
ax.ax_joint.set_ylabel('Binding energy (kcal/mol)', size=18)
#plt.xlabel("Distance Met-loop to T1 Cu (ang)", fontsize=20)
#plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
# Out:
# Text(28.25,0.5,'Binding energy (kcal/mol)')

# %%
#Dist H451<12 ALL 2F4 siteB
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=df2f4B[ (df2f4B["Binding energy"] < -6) & (df2f4B["DOCKING_POSE"] < 4) & (df2f4B["Dist ABTS-H451"] <=12)], x="Dist ABTS-H451", y="Binding energy", color='orange', alpha=0.6,xlim=[0,12],ylim=[-10,-6])
ax.ax_joint.set_xlabel('Distance ABTS to H451 (ang)', size=18)
ax.ax_joint.set_ylabel('Binding energy (kcal/mol)', size=18)
ax.ax_joint.set_xticklabels([0,2,4,6,8,10,12], size = 16)
ax.ax_joint.set_yticklabels([-10.0,-9.5,-9.0,-8.5,-8.0,-7.5,-7.0,-6.5,-6.0], size = 16)
plt.savefig("./VINADocking_siteB_2F4-histo-H451-12A-blueorange.png", bbox_inches='tight', dpi=600)

# %% [markdown]
# ## Site D

# %%
# Binding energy vs Dist ABTS-T1 SITED
df = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT-siteD-pose3.csv")
x = df["Dist ABTS-T1"].values
xTNC = df["Dist ABTS-TNC"].values
xH = df["Dist ABTS-H514"].values
y = df["Binding energy"].values

distCu = df["Dist Cu-loop"].values

df2 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4-siteD-pose3.csv")
x2 = df2["Dist ABTS-T1"].values
x2TNC = df2["Dist ABTS-TNC"].values
x2H = df2["Dist ABTS-H514"].values
y2 = df2["Binding energy"].values
dist2Cu = df2["Dist Cu-loop"].values

#Plot figure
plt.figure()
plt.plot(x, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2, y2, "x", c="orange", markersize=5, label='2F4', alpha=0.5)

plt.xlabel("Distance from T1 Cu (ang)", fontsize=14)
plt.ylabel("Binding energy (kcal/mol)", fontsize=14)
plt.title ("ABTS siteD docking", fontsize=14)
plt.ylim(-12,-3)
plt.xlim(0,30)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteD-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#To TNC distance
#Plot figure
plt.figure()
plt.plot(xTNC, y, "o", c="steelblue", markersize=8, label='WT')
plt.plot(x2TNC, y2, "o", c="orange", markersize=5, label='2F4', alpha=0.5)

plt.xlabel("Distance from TNC (ang)", fontsize=14)
plt.ylabel("Binding energy (kcal/mol)", fontsize=14)
plt.title ("ABTS siteD docking", fontsize=14)
plt.ylim(-12,-3)
plt.xlim(0,30)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteD_TNC-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#TNC dist vs loop-Cu distance
#Plot figure
plt.figure()
plt.plot(xTNC, distCu, "v", c="steelblue", markersize=8, label='WT')
plt.plot(x2TNC, dist2Cu, "v", c="orange", markersize=8, label='2F4', alpha=0.5)

plt.xlabel("Distance from TNC (ang)", fontsize=14)
plt.ylabel("Distance Cu-loop (ang)", fontsize=14)
plt.title ("ABTS siteD docking", fontsize=14)
plt.ylim(10,30)
plt.xlim(0,30)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteD_TNC_loop-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot figure
#Plot figure
plt.figure()
plt.plot(xTNC, xH, "o", c="steelblue", markersize=8, label='WT')
plt.plot(x2TNC, x2H, "o", c="orange", markersize=5, label='2F4', alpha=0.5)

plt.xlabel("Distance from TNC (ang)", fontsize=14)
plt.ylabel("Distance ABTS-H514 (ang)", fontsize=14)
plt.title ("ABTS siteD docking", fontsize=14)
plt.ylim(0,20)
plt.xlim(0,30)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteD_H514-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

# %% [markdown]
# # Site C and A3

# %%
# Binding energy vs Dist ABTS-T1 SITEC and A3!!!***
df = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT-siteA3-pose3.csv")
x = df["Dist ABTS-T1"].values
xH451 = df["Dist ABTS-H451"].values
xH514 = df["Dist ABTS-H514"].values
y = df["Binding energy"].values

distCu = df["Dist Cu-loop"].values

df2 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4-siteC-pose3.csv")
x2 = df2["Dist ABTS-T1"].values
x2H451 = df2["Dist ABTS-H451"].values
x2H514 = df2["Dist ABTS-H514"].values
y2 = df2["Binding energy"].values

#Plot figure
plt.figure()
plt.plot(x, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2, y2, "x", c="orange", markersize=5, label='2F4')
plt.xlabel("Distance from T1 Cu (ang)", fontsize=14)
plt.ylabel("Binding energy (kcal/mol)", fontsize=14)
plt.title ("ABTS siteC docking", fontsize=14)
plt.ylim(-12,-4)
plt.xlim(0,25)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteC-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot vs H451 distance
plt.figure()
plt.plot(xH451, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2H451, y2, "x", c="orange", markersize=5, label='2F4')

plt.xlabel("Distance ABTS-H451 (ang)", fontsize=14)
plt.ylabel("Binding energy (kcal/mol)", fontsize=14)
plt.title ("ABTS siteC docking", fontsize=14)
plt.ylim(-12,-4)
plt.xlim(0,10)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteC_H451-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot vs H514 distance
plt.figure()
plt.plot(xH514, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2H514, y2, "x", c="orange", markersize=5, label='2F4')

plt.xlabel("Distance ABTS-H514 (ang)", fontsize=14)
plt.ylabel("Binding energy (kcal/mol)", fontsize=14)
plt.title ("ABTS siteC docking", fontsize=14)
plt.ylim(-12,-4)
plt.xlim(0,10)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteC_H514-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

# %%
# Binding energy vs Dist Cu-Loop
df = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT.csv")
x = df["Dist Cu-loop"].values
y = df["Binding energy"].values

distCu = df["Dist Cu-loop"].values

df2 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4.csv")
x2 = df2["Dist Cu-loop"].values
y2 = df2["Binding energy"].values

#Plot figure
plt.figure()
plt.plot(x, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2, y2, "x", c="orange", markersize=5, label='2F4', alpha=0.5)

plt.xlabel("Distance Cu-loop (ang)", fontsize=14)
plt.ylabel("Binding energy (kcal/mol)", fontsize=14)
plt.title ("ABTS global docking", fontsize=14)
plt.ylim(-12,-5)
plt.xlim(10,30)
plt.legend(loc=4)

plt.savefig("./VINADocking_global_Cu-loop-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

# %% [markdown]
# ## Site A-C-F (A)

# %%
# Binding energy vs Dist ABTS-T1 SITEA-C-F
plt.clf()
df = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT-siteA-C-F-pose3.csv")
x = df["Dist ABTS-T1"].values
xH451 = df["Dist ABTS-H451"].values
xH514 = df["Dist ABTS-H514"].values
y = df["Binding energy"].values

distCu = df["Dist Cu-loop"].values

df2 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4-siteA-C-F-pose3.csv")
x2 = df2["Dist ABTS-T1"].values
x2H451 = df2["Dist ABTS-H451"].values
x2H514 = df2["Dist ABTS-H514"].values
y2 = df2["Binding energy"].values

#Plot figure
plt.figure(figsize=(8,8))
plt.plot(x, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2, y2, "x", c="orange", markersize=5, label='2F4')
plt.xlabel("Distance ABTS to T1 Cu (ang)", fontsize=22)
plt.ylabel("Binding energy (kcal/mol)", fontsize=22)
#plt.title ("ABTS siteA-C-F docking", fontsize=14)
plt.ylim(-12,-5)
plt.xlim(0,25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteA-C-F-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot vs H451 distance
plt.figure(figsize=(8,8))
plt.plot(xH451, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2H451, y2, "x", c="orange", markersize=5, label='2F4')

plt.xlabel("Distance ABTS to H451 (ang)", fontsize=22)
plt.ylabel("Binding energy (kcal/mol)", fontsize=22)
#plt.title ("ABTS siteA-C-F docking", fontsize=22)
plt.ylim(-12,-5)
plt.xlim(0,10)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteA-C-F_H451-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

#Plot vs H514 distance
plt.figure(figsize=(8,8))
plt.plot(xH514, y, "x", c="steelblue", markersize=8, label='WT')
plt.plot(x2H514, y2, "x", c="orange", markersize=5, label='2F4')

plt.xlabel("Distance ABTS to H514 (ang)", fontsize=22)
plt.ylabel("Binding energy (kcal/mol)", fontsize=22)
#plt.title ("ABTS siteA-C-F docking", fontsize=14)
plt.ylim(-12,-5)
plt.xlim(0,10)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc=4)
plt.savefig("./VINADocking_siteA-C-F_H514-blueorange.png", bbox_inches='tight', dpi=600)
#plt.clf()

# %%
#Plot histogram of distances
dfC2 = pd.read_csv("./Analysis_C2.csv")
dfC3 = pd.read_csv("./Analysis_C3.csv")

# %%
sns.jointplot(data=info_open[ (dfC2["Binding_Energy"] < 200)], x="Dist_ligand_FAD", y="Dist345",color='steelblue', alpha=0.6)
sns.jointplot(data=info_open[ (dfC2["Binding_Energy"] < 200)], x="Dist_Hcat_ligand", y="Dist345",color='steelblue', alpha=0.6)
# Out:
# /tmp/ipykernel_209/2687224833.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.jointplot(data=info_open[ (dfC2["Binding_Energy"] < 200)], x="Dist_ligand_FAD", y="Dist345",color='steelblue', alpha=0.6)
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 sns.jointplot(data=info_open[ (dfC2["Binding_Energy"] < 200)], x="Dist_ligand_FAD", y="Dist345",color='steelblue', alpha=0.6)
#       2 sns.jointplot(data=info_open[ (dfC2["Binding_Energy"] < 200)], x="Dist_Hcat_ligand", y="Dist345",color='steelblue', alpha=0.6)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
# ...

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist55"].plot.kde(bw_method= 0.3) #C2 blue
hist_C3 = dfC3["Dist55"].plot.kde(bw_method= 0.3) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Man-K55 (Å)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./R94-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist55"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist55"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-K55 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-K55-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist94"].plot.kde(bw_method= 0.4) #C2 blue
hist_C3 = dfC3["Dist94"].plot.kde(bw_method= 0.4) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Mang-R94 (Å)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./R94-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist94"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist94"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-R94 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-R94-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist297"].plot.kde(bw_method= 0.3) #C2 blue
hist_C3 = dfC3["Dist297"].plot.kde(bw_method= 0.3) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Mang-Q297 (Å)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./Q297-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist297"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist297"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-Q297 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-Q297-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist340"].plot.kde(bw_method= 0.2) #C2 blue
hist_C3 = dfC3["Dist340"].plot.kde(bw_method= 0.2) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Man-Q340 (Å)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig("./Q340-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist340"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist340"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-Q340 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-Q340-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist345"].plot.kde(bw_method= 0.2) #C2 blue
hist_C3 = dfC3["Dist345"].plot.kde(bw_method= 0.2) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Man-Q345 (Å)", fontsize=22)
plt.xlim(0, 15)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig("./Q345-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist345"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist345"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-D345 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-D345-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist_ligand_FAD"].plot.kde(bw_method= 0.3) #C2 blue
hist_C3 = dfC3["Dist_ligand_FAD"].plot.kde(bw_method= 0.3) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Man-FAD (Å)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 

plt.savefig("./FAD-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist_ligand_FAD"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist_ligand_FAD"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-FAD (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-FAD-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Dist_Hcat_ligand"].plot.kde(bw_method= 0.3) #C2 blue
hist_C3 = dfC3["Dist_Hcat_ligand"].plot.kde(bw_method= 0.3) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Distance Man-H440 (Å)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 

plt.savefig("./H440-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist_Hcat_ligand"], bins='freedman', facecolor='steelblue', alpha=0.8, rwidth=0.7) #C2 blue
hist_C3 = hist(dfC3["Dist_Hcat_ligand"], bins='freedman', facecolor='orange', alpha=0.5, rwidth=0.7) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-H440 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-H440-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist_Hcat_ligand"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist_Hcat_ligand"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-H440 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-H440-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Energy_ligand"].plot.kde(bw_method= 0.4) #C2 blue
hist_C3 = dfC3["Energy_ligand"].plot.kde(bw_method= 0.4) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Energy Man (kcal/mol)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 

plt.savefig("./Energy-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Dist129"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Dist129"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Distance Mang-T129 (Å)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-T129-Man-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Energy_ligand"], bins='freedman', facecolor='steelblue', alpha=0.8) #C2 blue
hist_C3 = hist(dfC3["Energy_ligand"], bins='freedman', facecolor='orange', alpha=0.5) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Energy ligand (kcal/mol)", fontsize=22)

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-Energy-ligand-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Binding_Energy"].plot.kde(bw_method= 0.4) #C2 blue
hist_C3 = dfC3["Binding_Energy"].plot.kde(bw_method= 0.4) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Binding Energy (kcal/mol)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 

plt.savefig("./BindingE-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Binding_Energy"], bins='freedman', facecolor='steelblue', alpha=0.8, edgecolor='black', linewidth=1.2) #C2 blue
hist_C3 = hist(dfC3["Binding_Energy"], bins='freedman', facecolor='orange', alpha=0.5, edgecolor='black', linewidth=1.2) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Binding Energy (kcal/mol)", fontsize=22)
plt.ylim([0, 13])

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./hist-Binding-Energy-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Energy_all"].plot.kde(bw_method= 0.4) #C2 blue
hist_C3 = dfC3["Energy_all"].plot.kde(bw_method= 0.4) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Total Energy (kcal/mol)", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 

plt.savefig("./Total-Energy-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = dfC2["Score"].plot.kde(bw_method= 0.4) #C2 blue
hist_C3 = dfC3["Score"].plot.kde(bw_method= 0.4) #C3 orange

plt.ylabel("Density", fontsize=22)
plt.xlabel("Score", fontsize=22)
plt.grid(axis='x')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 

plt.savefig("./Score-blueorange.png", bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
hist_C2 = hist(dfC2["Score"], bins='freedman', facecolor='steelblue', alpha=0.8) #C2 blue
hist_C3 = hist(dfC3["Score"], bins='freedman', facecolor='orange', alpha=0.5) #C3 orange
plt.ylabel("Number of events", fontsize=22)
plt.xlabel("Score", fontsize=22)

plt.grid(axis='x')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./Score-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#SiteA-C-F
#ABTS-TH514 distance for those with ABTS-T1<10 ang
#dfwt = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/wt/dockingAnalysis_bydist-WT-siteA-C-F-pose3.csv")
#df2f4 = pd.read_csv("/home/lmasgrau/BLIG/McoA/DOCKING/analysis/2f4/dockingAnalysis_bydist-2F4-siteA-C-F-pose3.csv")
#col = "Dist ABTS-T1"
#for index, row in dfwt.iterrows():
#    if row[col] <= 10.:
plt.figure(figsize=(8,8))
histwth514 = dfwt["Dist ABTS-H514"].hist(bins=40, facecolor='steelblue', alpha=0.8)
hist2f4h514 = df2f4["Dist ABTS-H514"].hist(bins=40, facecolor='orange', alpha=0.65)
plt.xlabel("Distance ABTS to H514 (ang)", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("./VINADocking_siteA-C-F_histo-H514-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#SiteA-C-F
#ABTS-H451 distance
histwth451 = dfwt["Dist ABTS-H451"].hist(bins=40, facecolor='steelblue', alpha=0.8)
hist2f4h451 = df2f4["Dist ABTS-H451"].hist(bins=40, facecolor='orange', alpha=0.65)
plt.xlabel("Distance ABTS to H451 (ang)", fontsize=14)
plt.ylabel("Number of events", fontsize=14)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.figure(figsize=[10,8])
plt.savefig("./VINADocking_siteA-C-F_histo-H451-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-H451 and H514 distance siteA-C-F
plt.figure(figsize=(8,8))
histwth451 = dfwt["Dist ABTS-H514"].hist(bins=40, facecolor='steelblue', label='wt(H451)', alpha=0.9)
hist2f4h451 = df2f4["Dist ABTS-H514"].hist(bins=40, facecolor='orange', label='2f4(H451)', alpha=0.8)
histwth514 = dfwt["Dist ABTS-H451"].hist(bins=40, facecolor='lightslategrey', label='wt(H514)', alpha=0.7)
#histwth514 = dfwt["Dist ABTS-H451"].hist(bins=40, facecolor='lavender', label='wt(H514)', alpha=1.0)
hist2f4h514 = df2f4["Dist ABTS-H451"].hist(bins=40, facecolor='tan', label='2f4(H514)', alpha=0.8)
#hist2f4h514 = df2f4["Dist ABTS-H451"].hist(bins=40, facecolor='honeydew', label='2f4(H514)', alpha=0.8)
plt.xlabel("Distance ABTS to His514 and His451 (ang)", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(loc='best')
plt.savefig("./VINADocking_siteA-C-F_histo-H514-H451-blueorange.png", bbox_inches='tight', dpi=600)

# %%
#ABTS-H451 and H514 distance siteA-C-F
plt.figure(figsize=(8,8))
histwth451 = dfwt["Dist ABTS-H514"].hist(bins=40, facecolor='steelblue', label='wt(H451)', alpha=0.9)
hist2f4h451 = df2f4["Dist ABTS-H514"].hist(bins=40, facecolor='orange', label='2f4(H451)', alpha=0.8)
histwth514 = dfwt["Dist ABTS-H451"].hist(bins=40, facecolor='lightslategrey', label='wt(H514)', alpha=0.7)
#histwth514 = dfwt["Dist ABTS-H451"].hist(bins=40, facecolor='lavender', label='wt(H514)', alpha=1.0)
hist2f4h514 = df2f4["Dist ABTS-H451"].hist(bins=40, facecolor='tan', label='2f4(H514)', alpha=0.7)
#hist2f4h514 = df2f4["Dist ABTS-H451"].hist(bins=40, facecolor='honeydew', label='2f4(H514)', alpha=0.8)
plt.xlabel("Distance ABTS to His514 and His451 (ang)", fontsize=22)
plt.ylabel("Number of events", fontsize=22)
plt.ylim(0,1500)
plt.grid(axis='x')
plt.xlim(0,12)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(loc='best')
plt.savefig("./VINADocking_siteA-C-F_histo-H514-H451-12A-blueorange.png", bbox_inches='tight', dpi=600)

# %%
# Results for ALL conformations WT siteA-C-F but close to H514
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfC2[ (dfC2["Binding_Energy"] < 100)], x="Dist_ligand_FAD", y="Binding_Energy", color='steelblue', alpha=0.6,xlim=[0,7],ylim=[0,100])
ax.ax_joint.set_xlabel('Distance Glc-FAD', size=18)
ax.ax_joint.set_ylabel('Binding Energy (kcal/mol)', size=18)
#plt.xlabel("Distance Met-loop to T1 Cu (ang)", fontsize=20)
#plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
# Out:
# Text(23.875, 0.5, 'Binding Energy (kcal/mol)')

# %%
# Results for ALL conformations WT siteA-C-F but close to H514
plt.figure(figsize=(8,8))
ax = sns.jointplot(data=dfC3[ (dfC3["Binding_Energy"] < 100)], x="Dist_ligand_FAD", y="Binding_Energy", color='orange', alpha=0.6,xlim=[0,7],ylim=[0,100])
ax.ax_joint.set_xlabel('Distance Glc-FAD', size=18)
ax.ax_joint.set_ylabel('Binding Energy (kcal/mol)', size=18)
#plt.xlabel("Distance Met-loop to T1 Cu (ang)", fontsize=20)
#plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
# Out:
# Text(23.875, 0.5, 'Binding Energy (kcal/mol)')
